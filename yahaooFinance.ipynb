# %% [markdown]
# #### Install Yahoo finance library using pip
# ### python version : 3.11.4
# #####  https://github.com/ranaroussi/yfinance

# %%
pip install yfinance --upgrade --no-cache-dir
# Out:
# ...
#   Obtaining dependency information for yfinance from https://files.pythonhosted.org/packages/d5/b5/70bb98ee38ce532ee29fab76fb668382291fe6e1aa69a8c1ac7e6bc108e7/yfinance-0.2.38-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for multitasking>=0.0.7 from https://files.pythonhosted.org/packages/3e/8a/bb3160e76e844db9e69a413f055818969c8acade64e1a9ac5ce9dfdcf6c1/multitasking-0.0.11-py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/315.9 kB ? eta -:--:--
#      ----------- --------------------------- 92.2/315.9 kB 2.6 MB/s eta 0:00:01
#      -------------------------------------- 315.9/315.9 kB 3.9 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
# ...

# %%
import yfinance as yf

msft = yf.Ticker("MSFT")

# get all stock info
msft.info

# get historical market data
hist = msft.history(period="1mo")

# show meta information about the history (requires history() to be called first)
msft.history_metadata

# show actions (dividends, splits, capital gains)
msft.actions
msft.dividends
msft.splits
msft.capital_gains  # only for mutual funds & etfs

# show share count
msft.get_shares_full(start="2022-01-01", end=None)

# show financials:
# - income statement
msft.income_stmt
msft.quarterly_income_stmt
# - balance sheet
msft.balance_sheet
msft.quarterly_balance_sheet
# - cash flow statement
msft.cashflow
msft.quarterly_cashflow
# see `Ticker.get_income_stmt()` for more options

# show holders
msft.major_holders
msft.institutional_holders
msft.mutualfund_holders
msft.insider_transactions
msft.insider_purchases
msft.insider_roster_holders

# show recommendations
msft.recommendations
msft.recommendations_summary
msft.upgrades_downgrades

# Show future and historic earnings dates, returns at most next 4 quarters and last 8 quarters by default. 
# Note: If more are needed use msft.get_earnings_dates(limit=XX) with increased limit argument.
msft.earnings_dates

# show ISIN code - *experimental*
# ISIN = International Securities Identification Number
msft.isin

# show options expirations
msft.options

# show news
msft.news

# get option chain for specific expiration
opt = msft.option_chain('YYYY-MM-DD')
# data available via: opt.calls, opt.puts
# Out:
# C:\Users\jhauj\anaconda3\Lib\site-packages\yfinance\scrapers\history.py:408: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 63
#      60 msft.news
#      62 # get option chain for specific expiration
# ---> 63 opt = msft.option_chain('YYYY-MM-DD')
#
# File ~\anaconda3\Lib\site-packages\yfinance\ticker.py:91, in Ticker.option_chain(self, date, tz)
#      89     self._download_options()
#      90 if date not in self._expirations:
# ---> 91     raise ValueError(
#      92         f"Expiration `{date}` cannot be found. "
#      93         f"Available expirations are: [{', '.join(self._expirations)}]")
#      94 date = self._expirations[date]
# ...

# %%
## get information for 1 stock
msft.info
# Out:
# {'address1': 'One Microsoft Way',
#  'city': 'Redmond',
#  'state': 'WA',
#  'zip': '98052-6399',
#  'country': 'United States',
#  'phone': '425 882 8080',
#  'website': 'https://www.microsoft.com',
#  'industry': 'Software - Infrastructure',
#  'industryKey': 'software-infrastructure',
#  'industryDisp': 'Software - Infrastructure',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %%
import yfinance as yf

msft = yf.Ticker("MSFT")
msft.history(period="60mo")

df = msft.history(period="60mo")
df.to_csv('open_high_low_dividends_stock_split.csv')
df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2019-05-13 00:00:00-04:00  118.139357  119.510084  117.120832  117.415916
# 2019-05-14 00:00:00-04:00  117.910902  119.824201  117.749075  118.729530
# 2019-05-15 00:00:00-04:00  118.719970  121.060736  118.184933  120.401497
# 2019-05-16 00:00:00-04:00  121.098971  123.611719  120.821899  123.181770
# 2019-05-17 00:00:00-04:00  122.589413  124.643566  122.216802  122.360123
# ...                               ...         ...         ...         ...
# 2024-05-06 00:00:00-04:00  408.760010  413.929993  406.369995  413.540009
# 2024-05-07 00:00:00-04:00  414.660004  414.670013  409.089996  409.339996
# 2024-05-08 00:00:00-04:00  408.170013  412.230011  406.709991  410.540009
# 2024-05-09 00:00:00-04:00  410.570007  412.720001  409.100006  412.320007
# 2024-05-10 00:00:00-04:00  412.940002  415.380005  411.799988  414.739990
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %%
msft.options
# Out:
# ('2024-05-17',
#  '2024-05-24',
#  '2024-05-31',
#  '2024-06-07',
#  '2024-06-14',
#  '2024-06-21',
#  '2024-06-28',
#  '2024-07-19',
#  '2024-08-16',
#  '2024-09-20',
#  '2024-10-18',
#  '2024-11-15',
#  '2024-12-20',
#  '2025-01-17',
#  '2025-03-21',
#  '2025-06-20',
#  '2025-09-19',
#  '2025-12-19',
#  '2026-01-16',
#  '2026-06-18',
#  '2026-12-18')

# %%
msft.history_metadata
# Out:
# {'currency': 'USD',
#  'symbol': 'MSFT',
#  'exchangeName': 'NMS',
#  'fullExchangeName': 'NasdaqGS',
#  'instrumentType': 'EQUITY',
#  'firstTradeDate': 511108200,
#  'regularMarketTime': 1715371201,
#  'hasPrePostMarketData': True,
#  'gmtoffset': -14400,
#  'timezone': 'EDT',
#  'exchangeTimezoneName': 'America/New_York',
#  'regularMarketPrice': 414.74,
#  'fiftyTwoWeekHigh': 415.38,
#  'fiftyTwoWeekLow': 411.8,
#  'regularMarketDayHigh': 415.38,
#  'regularMarketDayLow': 411.8,
#  'regularMarketVolume': 12459034,
#  'chartPreviousClose': 127.13,
#  'priceHint': 2,
#  'currentTradingPeriod': {'pre': {'timezone': 'EDT',
#    'start': 1715328000,
#    'end': 1715347800,
#    'gmtoffset': -14400},
#   'regular': {'timezone': 'EDT',
#    'start': 1715347800,
#    'end': 1715371200,
#    'gmtoffset': -14400},
#   'post': {'timezone': 'EDT',
#    'start': 1715371200,
#    'end': 1715385600,
#    'gmtoffset': -14400}},
#  'dataGranularity': '1d',
#  'range': '60mo',
# ...

# %%
df = msft.quarterly_cashflow
df.to_json('output.json')

msft.quarterly_cashflow
# Out:
#                                                    2024-03-31     2023-12-31  \
# Free Cash Flow                                  20965000000.0   9118000000.0
# Repurchase Of Capital Stock                     -4213000000.0  -4000000000.0
# Repayment Of Debt                              -11589000000.0  -2916000000.0
# Issuance Of Debt                                 6352000000.0  10773000000.0
# Issuance Of Capital Stock                         522000000.0    261000000.0
# Capital Expenditure                            -10952000000.0  -9735000000.0
# End Cash Position                               19634000000.0  17305000000.0
# Beginning Cash Position                         17305000000.0  80452000000.0
# Effect Of Exchange Rate Changes                   -80000000.0     72000000.0
# Changes In Cash                                  2409000000.0 -63219000000.0
# Financing Cash Flow                            -18808000000.0 -10147000000.0
# ...

# %%
msft.quarterly_income_stmt
# Out:
#                                                        2024-03-31  \
# Tax Effect Of Unusual Items                           -33660000.0
# Tax Rate For Calcs                                           0.18
# Normalized EBITDA                                   33741000000.0
# Total Unusual Items                                  -187000000.0
# Total Unusual Items Excluding Goodwill               -187000000.0
# Net Income From Continuing Operation Net Minori...  21939000000.0
# Reconciled Depreciation                              6027000000.0
# Reconciled Cost Of Revenue                          18505000000.0
# EBITDA                                              33554000000.0
# EBIT                                                27527000000.0
# Net Interest Income                                  -181000000.0
# Interest Expense                                      800000000.0
# Interest Income                                       619000000.0
# ...

# %%
df = msft.get_shares_full(start="2018-01-01", end=None)
df.to_csv('filename.csv')
df
# Out:
# 2018-11-14 00:00:00-05:00    7676219904
# 2018-11-15 00:00:00-05:00    7676219904
# 2018-11-19 00:00:00-05:00    7676219904
# 2018-11-21 00:00:00-05:00    7676219904
# 2018-11-22 00:00:00-05:00    7676219904
#                                 ...
# 2024-05-01 00:00:00-04:00    7432309760
# 2024-05-01 00:00:00-04:00    7678949888
# 2024-05-07 00:00:00-04:00    7432309760
# 2024-05-10 00:00:00-04:00    7432309760
# 2024-05-11 00:00:00-04:00    7432309760
# Length: 405, dtype: int64

# %%
df =msft.get_earnings_dates(limit=30)
df.to_csv('earnings_data.csv')
df
# Out:
#                            EPS Estimate  Reported EPS  Surprise(%)
# Earnings Date
# 2025-04-23 16:00:00-04:00           NaN           NaN          NaN
# 2025-01-28 16:00:00-05:00           NaN           NaN          NaN
# 2024-12-06 11:00:00-05:00           NaN           NaN          NaN
# 2024-10-22 06:00:00-04:00           NaN           NaN          NaN
# 2024-07-23 06:00:00-04:00          2.93           NaN          NaN
# 2024-05-29 13:00:00-04:00           NaN           NaN          NaN
# 2024-05-21 08:00:00-04:00           NaN           NaN          NaN
# 2024-04-25 16:00:00-04:00          2.82          2.94       0.0433
# 2024-03-06 18:00:00-05:00          2.78          2.93       0.0540
# 2024-01-30 16:00:00-05:00          2.78          2.93       0.0534
# 2023-10-24 16:00:00-04:00          2.65          2.99       0.1270
# 2023-07-25 16:00:00-04:00          2.55          2.69       0.0549
# 2023-04-25 16:00:00-04:00          2.23          2.45       0.0981
# ...

# %%
msft.options
# Out:
# ('2024-05-17',
#  '2024-05-24',
#  '2024-05-31',
#  '2024-06-07',
#  '2024-06-14',
#  '2024-06-21',
#  '2024-06-28',
#  '2024-07-19',
#  '2024-08-16',
#  '2024-09-20',
#  '2024-10-18',
#  '2024-11-15',
#  '2024-12-20',
#  '2025-01-17',
#  '2025-03-21',
#  '2025-06-20',
#  '2025-09-19',
#  '2025-12-19',
#  '2026-01-16',
#  '2026-06-18',
#  '2026-12-18')

# %%
msft.option_chain('2024-05-17')
# Out:
# Options(calls=         contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0   MSFT240517C00160000 2024-03-21 16:06:17+00:00   160.0     271.45  237.65
# 1   MSFT240517C00175000 2023-10-05 18:32:20+00:00   175.0     149.00  180.45
# 2   MSFT240517C00190000 2024-02-13 16:16:18+00:00   190.0     221.50  236.15
# 3   MSFT240517C00200000 2024-05-10 17:56:19+00:00   200.0     214.07  213.80
# 4   MSFT240517C00205000 2024-01-18 18:37:22+00:00   205.0     188.85  200.25
# ..                  ...                       ...     ...        ...     ...
# 82  MSFT240517C00550000 2024-04-23 17:42:24+00:00   550.0       0.02    0.00
# 83  MSFT240517C00555000 2024-03-21 14:36:10+00:00   555.0       0.17    0.00
# 84  MSFT240517C00560000 2024-05-01 19:00:27+00:00   560.0       0.02    0.00
# 85  MSFT240517C00570000 2024-04-26 16:07:32+00:00   570.0       0.01    0.00
# 86  MSFT240517C00580000 2024-04-30 13:44:53+00:00   580.0       0.01    0.00
#
# ...
